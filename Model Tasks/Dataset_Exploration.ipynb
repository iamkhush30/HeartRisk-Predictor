# %% [markdown]
# <h1><b>Task 1: Problem Definition & Dataset Exploration</b></h1>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <h3>1: Load the dataset</h3>

# %%
df = pd.read_csv("cardio_train.csv", sep=';')
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %% [markdown]
# <h3>2: Get number of rows and columns</h3>

# %%
df.shape
# Out:
# (70000, 13)

# %% [markdown]
# <h3>3: Display column names</h3>

# %%
df.columns.tolist()
# Out:
# ['id',
#  'age',
#  'gender',
#  'height',
#  'weight',
#  'ap_hi',
#  'ap_lo',
#  'cholesterol',
#  'gluc',
#  'smoke',
#  'alco',
#  'active',
#  'cardio']

# %% [markdown]
# <h3>4: Show first few rows</h3>

# %%
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %% [markdown]
# <h3>5: Show last few rows</h3>

# %%
df.tail()
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# 69995      1     0       1       0
# 69996      0     0       1       1
# 69997      0     1       0       1
# 69998      0     0       0       1
# 69999      0     0       1       0

# %% [markdown]
# <h3>6: Data types of all columns</h3>

# %%
df.dtypes
# Out:
# id               int64
# age              int64
# gender           int64
# height           int64
# weight         float64
# ap_hi            int64
# ap_lo            int64
# cholesterol      int64
# gluc             int64
# smoke            int64
# alco             int64
# active           int64
# cardio           int64
# dtype: object

# %% [markdown]
# <h3>7: Dataset info (non-null counts, memory usage)</h3>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %% [markdown]
# <h3>8: Summary statistics for numeric columns</h3>

# %%
df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %% [markdown]
# <h3>9: Check for total missing values (confirmation)</h3>

# %%
df.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %% [markdown]
# <h3>10: Count duplicates</h3>

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# <h3>11: Unique value count per column</h3>

# %%
df.nunique()
# Out:
# id             70000
# age             8076
# gender             2
# height           109
# weight           287
# ap_hi            153
# ap_lo            157
# cholesterol        3
# gluc               3
# smoke              2
# alco               2
# active             2
# cardio             2
# dtype: int64

# %% [markdown]
# <h3>12: Value distribution of categorical columns</h3>

# %%
df['gender'].value_counts()
df['cholesterol'].value_counts()
df['gluc'].value_counts()
# Out:
# gluc
# 1    59479
# 3     5331
# 2     5190
# Name: count, dtype: int64

# %% [markdown]
# <h3>13: Convert age from days to years</h3>

# %%
df['age_years'] = (df['age'] / 365).astype(int)
df['age_years'].describe()
# Out:
# count    70000.000000
# mean        52.840671
# std          6.766774
# min         29.000000
# 25%         48.000000
# 50%         53.000000
# 75%         58.000000
# max         64.000000
# Name: age_years, dtype: float64

# %% [markdown]
# <h3>14: Minimum and maximum values using NumPy</h3>

# %%
np.min(df['age']), np.max(df['age'])
# Out:
# (np.int64(10798), np.int64(23713))

# %% [markdown]
# <h3>15: Mean and median of numeric columns using Pandas</h3>

# %%
df.mean(numeric_only=True)
df.median(numeric_only=True)
# Out:
# id             50001.5
# age            19703.0
# gender             1.0
# height           165.0
# weight            72.0
# ap_hi            120.0
# ap_lo             80.0
# cholesterol        1.0
# gluc               1.0
# smoke              0.0
# alco               0.0
# active             1.0
# cardio             0.0
# age_years         53.0
# dtype: float64

# %% [markdown]
# <h3>16: Mode of categorical columns</h3>

# %%
df.mode().iloc[0]
# Out:
# id                 0.0
# age            18236.0
# gender             1.0
# height           165.0
# weight            65.0
# ap_hi            120.0
# ap_lo             80.0
# cholesterol        1.0
# gluc               1.0
# smoke              0.0
# alco               0.0
# active             1.0
# cardio             0.0
# age_years         55.0
# Name: 0, dtype: float64

# %% [markdown]
# <h3>17: Variance and standard deviation</h3>

# %%
df.var(numeric_only=True)
df.std(numeric_only=True)
# Out:
# id             28851.302323
# age             2467.251667
# gender             0.476838
# height             8.210126
# weight            14.395757
# ap_hi            154.011419
# ap_lo            188.472530
# cholesterol        0.680250
# gluc               0.572270
# smoke              0.283484
# alco               0.225568
# active             0.397179
# cardio             0.500003
# age_years          6.766774
# dtype: float64

# %% [markdown]
# <h3>18: Correlation matrix between numeric features</h3>

# %%
df.corr(numeric_only=True)
# Out:
#                    id       age    gender    height    weight     ap_hi  \
# id           1.000000  0.003457  0.003502 -0.003038 -0.001830  0.003356
# age          0.003457  1.000000 -0.022811 -0.081515  0.053684  0.020764
# gender       0.003502 -0.022811  1.000000  0.499033  0.155406  0.006005
# height      -0.003038 -0.081515  0.499033  1.000000  0.290968  0.005488
# weight      -0.001830  0.053684  0.155406  0.290968  1.000000  0.030702
# ap_hi        0.003356  0.020764  0.006005  0.005488  0.030702  1.000000
# ap_lo       -0.002529  0.017647  0.015254  0.006150  0.043710  0.016086
# cholesterol  0.006106  0.154424 -0.035821 -0.050226  0.141768  0.023778
# gluc         0.002467  0.098703 -0.020491 -0.018595  0.106857  0.011841
# smoke       -0.003699 -0.047633  0.338135  0.187989  0.067780 -0.000922
# alco         0.001210 -0.029723  0.170966  0.094419  0.067113  0.001408
# active       0.003755 -0.009927  0.005866 -0.006570 -0.016867 -0.000033
# ...

# %% [markdown]
# <h3>19: Find which columns correlate most with target</h3>

# %%
df.corr(numeric_only=True)['cardio'].sort_values(ascending=False)
# Out:
# cardio         1.000000
# age            0.238159
# age_years      0.237985
# cholesterol    0.221147
# weight         0.181660
# gluc           0.089307
# ap_lo          0.065719
# ap_hi          0.054475
# gender         0.008109
# id             0.003799
# alco          -0.007330
# height        -0.010821
# smoke         -0.015486
# active        -0.035653
# Name: cardio, dtype: float64

# %% [markdown]
# <h3>20: Frequency table between gender and cardio</h3>

# %%
pd.crosstab(df['gender'], df['cardio'])
# Out:
# cardio      0      1
# gender
# 1       22914  22616
# 2       12107  12363

# %% [markdown]
# <h3>21: Proportion of smokers, drinkers, and active people</h3>

# %%
df[['smoke', 'alco', 'active']].mean()
# Out:
# smoke     0.088129
# alco      0.053771
# active    0.803729
# dtype: float64

# %% [markdown]
# <h3>22: Relationship between cholesterol and cardio outcome</h3>

# %%
df.groupby('cholesterol')['cardio'].mean()
# Out:
# cholesterol
# 1    0.440107
# 2    0.602157
# 3    0.765435
# Name: cardio, dtype: float64

# %% [markdown]
# <h3>23: Relationship between glucose level and cardio outcome</h3>

# %%
df.groupby('gluc')['cardio'].mean()
# Out:
# gluc
# 1    0.480590
# 2    0.593064
# 3    0.622022
# Name: cardio, dtype: float64
